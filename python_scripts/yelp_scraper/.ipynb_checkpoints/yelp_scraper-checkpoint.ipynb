# %%
# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from selenium import webdriver
import pandas as pd

# Get Search Information 
user_location = str(input("Enter Location: "))
user_search = str(input("Enter Business: "))

# Get URL For Top Hit in Search
search_url = "https://www.yelp.com/search?find_desc=" + user_search + "&find_loc=" + user_location
options = webdriver.ChromeOptions()
# options.add_argument('headless')
driver = webdriver.Chrome(options=options)
driver.get(search_url)
driver.implicitly_wait(15)
search_body = driver.find_element_by_id("yelp_main_body")
response = driver.page_source
search_soup = bs(response,"lxml")

# Get Page Source For Business Page
raw_links = search_soup.find_all("a", class_="link-color--blue-dark__373c0__1mhJo")
all_links = []
[all_links.append(link.get("href")) for link in raw_links]
business_page = "https://www.yelp.com" + all_links[9]
business_page

driver.get(business_page)
driver.implicitly_wait(15)
yelp_body = driver.find_elements_by_class_name("war-button")
response = driver.page_source
business_soup = bs(response,"lxml")
# Out:
# Enter Location: dc
# Enter Business: nicks riverside grill

# %%
raw_comments = business_soup.find_all("p",itemprop="description")
comments = []
[comments.append(comment.text) for comment in raw_comments]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
raw_published_dates = business_soup.find_all("meta",itemprop="datePublished")
published_dates = []

[published_dates.append(comment.get("content")) for comment in raw_published_dates]

raw_ratings = business_soup.find_all("meta",itemprop="ratingValue")
business_overall_rating = raw_ratings[0]
raw_ratings = raw_ratings[1:len(raw_ratings)]
ratings = []

[ratings.append(rating.get("content")) for rating in raw_ratings]

df = pd.DataFrame({"Published Date":published_dates,
                   "Comment": comments,
                   "Rating" : ratings})

# %%
df
# Out:
#    Published Date                                            Comment Rating
# 0      2018-11-23  Came here before seeing a movie nearby and I h...    4.0
# 1      2018-10-15  Food was delicious! \n\nThe wings alone was a ...    5.0
# 2      2019-02-02  I love the happy hour here. Great prices and e...    5.0
# 3      2018-07-14  Late night grub after hanging out in DC. This ...    4.0
# 4      2018-09-17  I've only ever had the chicken sandwich here b...    3.0
# 5      2018-11-11  This place has a great location on the waterfr...    3.0
# 6      2018-08-25  Saturday afternoon live DJ in the bar area fro...    5.0
# 7      2018-07-20  Why am I so in love with the sweet bread!!! Gr...    5.0
# 8      2018-07-05  AFFORDABILITY: More on the expensive side for ...    3.0
# 9      2017-11-30  Sat at the outdoor bar as we waited for our ta...    3.0
# 10     2018-05-27  This place won't split the check!...couldn't g...    2.0
# 11     2018-08-21  I absolutely loved this restaurant. Originally...    5.0
# 12     2019-01-23  Sub average food with sub average service. Not...    1.0
# 13     2018-12-08  Great service, great food, nice view. Would re...    5.0
# 14     2017-09-03  After reading some of the reviews I think this...    3.0
# 15     2018-11-17  It was ok. Had the crab cake sandwich with fri...    3.0
# 16     2018-06-01  Wish I would have read the reviews first. I wa...    1.0
# 17     2017-06-03  Know before you go: this place is so, so colle...    3.0
# 18     2018-11-09  Terrible terrible service!!! Food was pretty g...    1.0
# 19     2018-05-11  I am not one to yelp very often, but I feel so...    2.0

# %%
driver.quit()
